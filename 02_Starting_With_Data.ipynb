# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravneet-kaur1102/Python_Course/blob/main/02_Starting_With_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Date Created:* June 4, 2021
#
# *Time:* 7:35 AM (IST)
#
# *Author Name:* [Ravneet Kaur](https://github.com/Ravneet-kaur1102)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/PYTHON203_DATA_Carpentary'
# Out:
# /content/drive/MyDrive/PYTHON203_DATA_Carpentary

# %% [markdown]
#  This section will use the surveys.csv file that can be downloaded here: https://ndownloader.figshare.com/files/2292172
#
#  We will be working with pandas, numpy and matplotlib

# %%
import pandas as pd
pd.read_csv("surveys.csv") #reading the data frames from csv file
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# ...

# %% [markdown]
# Now we need to store the data for rest of the opeerations. For this we need to save the data in some variable.

# %%
dataframe = pd.read_csv("surveys.csv")
dataframe
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# ...

# %% [markdown]
# for printing first few lines of the file, we need head() method

# %%
dataframe.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  weight
# 0          1      7   16  1977        2         NL   M             32.0     NaN
# 1          2      7   16  1977        3         NL   M             33.0     NaN
# 2          3      7   16  1977        2         DM   F             37.0     NaN
# 3          4      7   16  1977        7         DM   M             36.0     NaN
# 4          5      7   16  1977        3         DM   M             35.0     NaN

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
dataframe.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
dataframe.shape
# Out:
# (35549, 9)

# %%
dataframe.head(15)
# Out:
#     record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0           1      7   16  1977  ...          NL    M            32.0     NaN
# 1           2      7   16  1977  ...          NL    M            33.0     NaN
# 2           3      7   16  1977  ...          DM    F            37.0     NaN
# 3           4      7   16  1977  ...          DM    M            36.0     NaN
# 4           5      7   16  1977  ...          DM    M            35.0     NaN
# 5           6      7   16  1977  ...          PF    M            14.0     NaN
# 6           7      7   16  1977  ...          PE    F             NaN     NaN
# 7           8      7   16  1977  ...          DM    M            37.0     NaN
# 8           9      7   16  1977  ...          DM    F            34.0     NaN
# 9          10      7   16  1977  ...          PF    F            20.0     NaN
# 10         11      7   16  1977  ...          DS    F            53.0     NaN
# ...

# %%
dataframe.tail()
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# # Calculatig Statistics from Data in a Pandas Data Frame

# %%
dataframe.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
#listing all unique species

pd.unique(dataframe['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
pd.unique(dataframe['plot_id'])
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
site_names = pd.unique(dataframe['plot_id'])

# %%
site_names
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %% [markdown]
# #Difference between `len()` and `nunique`:
#
# nunique by default remove missing values.

# %%
len(site_names)
# Out:
# 24

# %%
dataframe['plot_id'].nunique()
# Out:
# 24

# %%
dataframe['species_id'].nunique()
# Out:
# 48

# %%
len('species_id')
# Out:
# 10

# %% [markdown]
# #Groups in Pandas

# %%
dataframe['weight'].describe() #calculates the basic statistics for all records in a single column
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
#individual
dataframe['weight'].max()
# Out:
# 280.0

# %%
dataframe['weight'].min()
# Out:
# 4.0

# %%
dataframe['weight'].count()
# Out:
# 32283

# %%
dataframe.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
Grouped_data=dataframe.groupby('year')

# %%
Grouped_data.describe()
# Out:
#      record_id                                ... weight
#          count     mean         std      min  ...    25%   50%     75%    max
# year                                          ...
# 1977     503.0    252.0  145.347859      1.0  ...   36.0  41.0   46.00  149.0
# 1978    1048.0   1027.5  302.675844    504.0  ...   36.0  45.0  114.00  232.0
# 1979     719.0   1911.0  207.701709   1552.0  ...   31.0  46.0   96.75  274.0
# 1980    1415.0   2978.0  408.619628   2271.0  ...   33.0  46.0   98.00  243.0
# 1981    1472.0   4421.5  425.074111   3686.0  ...   37.0  47.0  101.00  264.0
# 1982    1978.0   6146.5  571.143736   5158.0  ...   22.0  41.0   55.00  252.0
# 1983    1673.0   7972.0  483.097816   7136.0  ...   25.0  41.0   54.00  256.0
# 1984     981.0   9299.0  283.334608   8809.0  ...   28.0  41.0   49.00  259.0
# 1985    1438.0  10508.5  415.259156   9790.0  ...   32.0  41.0   48.00  225.0
# 1986     942.0  11698.5  272.076276  11228.0  ...   31.0  44.0   52.00  240.0
# ...

# %%
Grouped_data.mean()
# Out:
#       record_id     month        day    plot_id  hindfoot_length     weight
# year
# 1977      252.0  9.568588  14.986083  11.616302        36.276961  46.650376
# 1978     1027.5  6.560115   8.339695  10.822519        37.278880  67.911290
# 1979     1911.0  6.589708  23.025035  12.029207        35.167219  63.390282
# 1980     2978.0  5.942049  15.309541  11.649470        35.082035  62.448747
# 1981     4421.5  5.790082  13.550272  11.864130        35.538830  65.843888
# 1982     6146.5  6.280081  23.142568  11.943883        31.710897  53.765888
# 1983     7972.0  6.148834  15.041841  11.901375        32.390635  55.102828
# 1984     9299.0  6.486239  17.147808  11.697248        31.929385  50.955682
# 1985    10508.5  6.429764  17.654381  10.566064        32.617844  46.694570
# 1986    11698.5  7.366242   9.264331  11.032909        33.057444  55.053927
# 1987    13005.0  6.470975  19.435069  11.404548        29.553377  49.443639
# ...

# %%
Grouped_data.head()
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 33320      33321      1   12  2002  ...          DM    M            38.0    44.0
# 33321      33322      1   12  2002  ...          DO    M            37.0    58.0
# 33322      33323      1   12  2002  ...          PB    M            28.0    45.0
# 33323      33324      1   12  2002  ...          AB  NaN             NaN     NaN
# 33324      33325      1   12  2002  ...          DO    M            35.0    29.0
#
# ...

# %%
Grouped_data.head(5)
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 33320      33321      1   12  2002  ...          DM    M            38.0    44.0
# 33321      33322      1   12  2002  ...          DO    M            37.0    58.0
# 33322      33323      1   12  2002  ...          PB    M            28.0    45.0
# 33323      33324      1   12  2002  ...          AB  NaN             NaN     NaN
# 33324      33325      1   12  2002  ...          DO    M            35.0    29.0
#
# ...

# %%
Grouped_data1=dataframe.groupby(['sex','year'])

# %%
Grouped_data1.describe()
# Out:
#          record_id                            ... weight
#              count          mean         std  ...    50%     75%    max
# sex year                                      ...
# F   1977     204.0    242.343137  146.582783  ...   40.0   45.75  127.0
#     1978     503.0   1059.359841  292.294338  ...   45.0  116.00  212.0
#     1979     327.0   1915.168196  205.113718  ...   45.0  112.00  274.0
#     1980     605.0   2965.566942  424.263309  ...   43.0   68.25  214.0
#     1981     631.0   4414.838352  428.809329  ...   46.0   90.00  264.0
#     1982     823.0   6169.795869  575.625900  ...   40.0   62.00  248.0
#     1983     771.0   8029.924773  481.952298  ...   39.0   62.50  208.0
#     1984     445.0   9287.948315  289.392326  ...   40.0   48.00  205.0
#     1985     636.0  10503.482704  406.958689  ...   40.0   48.00  177.0
#     1986     414.0  11696.077295  263.175769  ...   42.0   52.00  214.0
#     1987     677.0  13008.007386  477.681901  ...   38.0   48.00  220.0
# ...

# %%
Grouped_data1.count()
# Out:
#           record_id  month   day  plot_id  species_id  hindfoot_length  weight
# sex year
# F   1977        204    204   204      204         204              195     130
#     1978        503    503   503      503         503              458     464
#     1979        327    327   327      327         327              303     320
#     1980        605    605   605      605         605              446     596
#     1981        631    631   631      631         631              489     620
#     1982        823    823   823      823         823              680     811
#     1983        771    771   771      771         771              768     759
#     1984        445    445   445      445         445              437     440
#     1985        636    636   636      636         636              631     627
#     1986        414    414   414      414         414              403     405
#     1987        677    677   677      677         677              598     668
# ...

# %%
Grouped_data1.mean()
# Out:
#              record_id     month  ...  hindfoot_length     weight
# sex year                          ...
# F   1977    242.343137  9.480392  ...        36.574359  47.607692
#     1978   1059.359841  6.910537  ...        38.303493  69.959052
#     1979   1915.168196  6.688073  ...        34.871287  65.562500
#     1980   2965.566942  5.872727  ...        33.226457  57.365772
#     1981   4414.838352  5.755943  ...        34.746421  63.404839
#     1982   6169.795869  6.408262  ...        31.960294  55.440197
#     1983   8029.924773  6.583658  ...        32.817708  55.868248
#     1984   9287.948315  6.366292  ...        32.178490  49.009091
#     1985  10503.482704  6.349057  ...        32.692552  47.121212
#     1986  11696.077295  7.347826  ...        32.483871  54.706173
#     1987  13008.007386  6.502216  ...        28.724080  48.907186
#     1988  14586.049669  6.177152  ...        27.408027  45.136895
#     1989  16127.412979  6.206490  ...        25.244444  36.053571
# ...

# %%
dataframe.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
by_site=dataframe.groupby('plot_id')

# %%
by_site['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %% [markdown]
# #Creating Summary Counts in Pandas

# %%
species_counts = dataframe.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
sex_count = dataframe.groupby('year')['sex'].count()
print(sex_count)
# Out:
# year
# 1977     418
# 1978     936
# 1979     651
# 1980    1332
# 1981    1376
# 1982    1850
# 1983    1568
# 1984     888
# 1985    1352
# 1986     869
# 1987    1539
# 1988    1341
# 1989    1458
# 1990    1217
# 1991    1243
# 1992     920
# 1993     665
# 1994     570
# 1995    1108
# 1996    1635
# 1997    2428
# 1998    1515
# 1999    1075
# 2000    1469
# 2001    1487
# 2002    2128
# Name: sex, dtype: int64

# %%
dataframe['species_id'].unique()
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
dataframe.groupby('species_id')['record_id'].count()['DO']
# Out:
# 3027

# %%
dataframe['sex'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
dataframe.groupby('sex')['year'].count()['F']
# Out:
# 15690

# %%
dataframe['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %% [markdown]
# #Graph Plotting
#
# ## 1. Inline Graph

# %%
# %matplotlib inline

species_counts.plot(kind='bar');

# %%
# %matplotlib inline 

year_count.plot(kind='bar')

# %%
total_count = dataframe.groupby('plot_id')['record_id'].nunique()
total_count.plot(kind='bar')

# %%
All_Species = dataframe.groupby('plot_id')['weight'].min()
All_Species.plot(kind='bar')

# %%
All_Species.plot(kind='bar')

# %% [markdown]
# #Create a plot of average weight across all species per site.

# %%
dataframe.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
dataframe['weight']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
# Name: weight, Length: 35549, dtype: float64

# %%
dataframe['weight'].unique()
# Out:
# array([ nan,  40.,  48.,  29.,  46.,  36.,  52.,   8.,  22.,  35.,   7.,
#          9.,  42.,  41.,  37.,  43.,  45.,  15.,  39.,  30.,  34.,  31.,
#         16.,  44.,  20.,  33.,  51.,  53.,  49.,   4.,  50.,  19.,  47.,
#         21.,  55.,  38.,  23.,  13.,  25., 117., 121., 115.,   6., 120.,
#        118., 126., 132., 113., 122., 107., 116., 137., 112., 114., 134.,
#        139., 127., 149., 138., 110., 150., 136., 135., 133., 141.,  24.,
#        157., 218., 124.,  56., 197., 154., 228., 144., 232., 128., 153.,
#         26., 146.,  28., 131., 125.,  69., 152.,  57.,  27.,  90., 148.,
#         76., 142.,  84.,  75., 168.,  87., 140., 225.,  18.,  89.,  73.,
#        123.,  59., 204., 212.,  91.,  83., 174.,  74., 130., 102., 182.,
#         68.,  97., 129., 108., 160.,  54., 100.,  64., 119.,  70.,  71.,
#         99.,  94.,  98.,  12., 200.,  17.,  82.,  32.,  58.,  81.,  93.,
#         95.,  85., 111., 105.,  96.,  86., 106.,  10., 190., 101.,  63.,
# ...

# %%
x = dataframe['weight'].unique()

# %%
y= dataframe['weight'].nunique()

# %%
avg = x/y

# %%
print(avg)
# Out:
# [       nan 0.15686275 0.18823529 0.11372549 0.18039216 0.14117647
#  0.20392157 0.03137255 0.08627451 0.1372549  0.02745098 0.03529412
#  0.16470588 0.16078431 0.14509804 0.16862745 0.17647059 0.05882353
#  0.15294118 0.11764706 0.13333333 0.12156863 0.0627451  0.17254902
#  0.07843137 0.12941176 0.2        0.20784314 0.19215686 0.01568627
#  0.19607843 0.0745098  0.18431373 0.08235294 0.21568627 0.14901961
#  0.09019608 0.05098039 0.09803922 0.45882353 0.4745098  0.45098039
#  0.02352941 0.47058824 0.4627451  0.49411765 0.51764706 0.44313725
#  0.47843137 0.41960784 0.45490196 0.5372549  0.43921569 0.44705882
#  0.5254902  0.54509804 0.49803922 0.58431373 0.54117647 0.43137255
#  0.58823529 0.53333333 0.52941176 0.52156863 0.55294118 0.09411765
#  0.61568627 0.85490196 0.48627451 0.21960784 0.77254902 0.60392157
#  0.89411765 0.56470588 0.90980392 0.50196078 0.6        0.10196078
#  0.57254902 0.10980392 0.51372549 0.49019608 0.27058824 0.59607843
# ...

# %%
Avg_Weight_Plot = dataframe.groupby('weight')['species_id'].nunique()
Avg_Weight_Plot.plot(kind='bar')
